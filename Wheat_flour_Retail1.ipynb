# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

from math import sqrt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Analysis imports
from pandas.plotting import lag_plot
from pylab import rcParams
from statsmodels.tsa.seasonal import seasonal_decompose
from pandas import DataFrame
from pandas import concat

# Modelling imports
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
from prophet import Prophet 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU, RNN
from keras.layers import Dropout

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/bangladesh-food-prices-2-1.xlsx')
df.head()
# Out:
#         date                cmname unit            category  price currency  \
# 0 2006-12-15  Wheat flour - Retail   KG  cereals and tubers   23.0      BDT
# 1 2007-01-15  Wheat flour - Retail   KG  cereals and tubers   25.5      BDT
# 2 2007-02-15  Wheat flour - Retail   KG  cereals and tubers   25.5      BDT
# 3 2007-03-15  Wheat flour - Retail   KG  cereals and tubers   26.0      BDT
# 4 2007-04-15  Wheat flour - Retail   KG  cereals and tubers   26.0      BDT
#
#       country  admname  adm1id           mktname  mktid  cmid  ptid  umid  \
# 0  Bangladesh  Barisal     575  Barisal Division    112    58    15     5
# 1  Bangladesh  Barisal     575  Barisal Division    112    58    15     5
# 2  Bangladesh  Barisal     575  Barisal Division    112    58    15     5
# 3  Bangladesh  Barisal     575  Barisal Division    112    58    15     5
# 4  Bangladesh  Barisal     575  Barisal Division    112    58    15     5
#
#    catid           sn  default
# 0      1  112_58_15_5      NaN
# 1      1  112_58_15_5      NaN
# 2      1  112_58_15_5      NaN
# 3      1  112_58_15_5      NaN
# 4      1  112_58_15_5      NaN

# %%
df=df.sort_values(by=['date'], ascending=True)

# %%
df
# Out:
#            date                    cmname unit            category   price  \
# 1241 2004-01-15    Rice (coarse) - Retail   KG  cereals and tubers  14.000
# 1242 2004-02-15    Rice (coarse) - Retail   KG  cereals and tubers  14.000
# 1243 2004-03-15    Rice (coarse) - Retail   KG  cereals and tubers  14.000
# 1244 2004-04-15    Rice (coarse) - Retail   KG  cereals and tubers  14.000
# 1245 2004-05-15    Rice (coarse) - Retail   KG  cereals and tubers  14.000
# ...         ...                       ...  ...                 ...     ...
# 1413 2018-08-15    Rice (coarse) - Retail   KG  cereals and tubers  38.873
# 948  2018-08-15  Lentils (masur) - Retail   KG     pulses and nuts  61.167
# 1240 2018-08-15      Wheat flour - Retail   KG  cereals and tubers  31.979
# 2012 2018-08-15    Rice (coarse) - Retail   KG  cereals and tubers  37.102
# 3385 2018-08-15       Oil (palm) - Retail    L        oil and fats  76.750
#
#      currency     country     admname  adm1id              mktname  mktid  \
# 1241      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# 1242      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# 1243      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# 1244      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# 1245      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# ...       ...         ...         ...     ...                  ...    ...
# 1413      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# 948       BDT  Bangladesh  Chittagong     576  Chittagong Division    114
# 1240      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# 2012      BDT  Bangladesh      Khulna     578      Khulna Division    118
# 3385      BDT  Bangladesh      Sylhet     580      Sylhet Division    122
#
#       cmid  ptid  umid  catid            sn  default
# 1241    60    15     5      1   116_60_15_5      NaN
# 1242    60    15     5      1   116_60_15_5      NaN
# 1243    60    15     5      1   116_60_15_5      NaN
# 1244    60    15     5      1   116_60_15_5      NaN
# 1245    60    15     5      1   116_60_15_5      NaN
# ...    ...   ...   ...    ...           ...      ...
# 1413    60    15     5      1   116_60_15_5      NaN
# 948     61    15     5      5   114_61_15_5      NaN
# 1240    58    15     5      1   116_58_15_5      NaN
# 2012    60    15     5      1   118_60_15_5      NaN
# 3385    62    15    15      6  122_62_15_15      NaN
#
# [3386 rows x 17 columns]

# %%
df=df.query('`cmname` == "Wheat flour - Retail"')

# %%
df
# Out:
#            date                cmname unit            category   price  \
# 1711 2005-10-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 1712 2005-11-15  Wheat flour - Retail   KG  cereals and tubers  19.000
# 1089 2005-11-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 1090 2005-12-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 501  2006-01-15  Wheat flour - Retail   KG  cereals and tubers  21.000
# ...         ...                   ...  ...                 ...     ...
# 2445 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  30.743
# 650  2018-08-15  Wheat flour - Retail   KG  cereals and tubers  32.335
# 1860 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  32.017
# 135  2018-08-15  Wheat flour - Retail   KG  cereals and tubers  31.212
# 1240 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  31.979
#
#      currency     country     admname  adm1id              mktname  mktid  \
# 1711      BDT  Bangladesh      Khulna     578      Khulna Division    118
# 1712      BDT  Bangladesh      Khulna     578      Khulna Division    118
# 1089      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# 1090      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
# 501       BDT  Bangladesh  Chittagong     576  Chittagong Division    114
# ...       ...         ...         ...     ...                  ...    ...
# 2445      BDT  Bangladesh    Rajshahi     579    Rajshahi Division    120
# 650       BDT  Bangladesh  Chittagong     576  Chittagong Division    114
# 1860      BDT  Bangladesh      Khulna     578      Khulna Division    118
# 135       BDT  Bangladesh     Barisal     575     Barisal Division    112
# 1240      BDT  Bangladesh       Dhaka     577       Dhaka Division    116
#
#       cmid  ptid  umid  catid           sn  default
# 1711    58    15     5      1  118_58_15_5      NaN
# 1712    58    15     5      1  118_58_15_5      NaN
# 1089    58    15     5      1  116_58_15_5      NaN
# 1090    58    15     5      1  116_58_15_5      NaN
# 501     58    15     5      1  114_58_15_5      NaN
# ...    ...   ...   ...    ...          ...      ...
# 2445    58    15     5      1  120_58_15_5      NaN
# 650     58    15     5      1  114_58_15_5      NaN
# 1860    58    15     5      1  118_58_15_5      NaN
# 135     58    15     5      1  112_58_15_5      NaN
# 1240    58    15     5      1  116_58_15_5      NaN
#
# [870 rows x 17 columns]

# %%
df.index  = df['date']
df
# Out:
#                  date                cmname unit            category   price  \
# date
# 2005-10-15 2005-10-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 2005-11-15 2005-11-15  Wheat flour - Retail   KG  cereals and tubers  19.000
# 2005-11-15 2005-11-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 2005-12-15 2005-12-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 2006-01-15 2006-01-15  Wheat flour - Retail   KG  cereals and tubers  21.000
# ...               ...                   ...  ...                 ...     ...
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  30.743
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  32.335
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  32.017
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  31.212
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  31.979
#
#            currency     country     admname  adm1id              mktname  \
# date
# 2005-10-15      BDT  Bangladesh      Khulna     578      Khulna Division
# 2005-11-15      BDT  Bangladesh      Khulna     578      Khulna Division
# 2005-11-15      BDT  Bangladesh       Dhaka     577       Dhaka Division
# 2005-12-15      BDT  Bangladesh       Dhaka     577       Dhaka Division
# 2006-01-15      BDT  Bangladesh  Chittagong     576  Chittagong Division
# ...             ...         ...         ...     ...                  ...
# 2018-08-15      BDT  Bangladesh    Rajshahi     579    Rajshahi Division
# 2018-08-15      BDT  Bangladesh  Chittagong     576  Chittagong Division
# 2018-08-15      BDT  Bangladesh      Khulna     578      Khulna Division
# 2018-08-15      BDT  Bangladesh     Barisal     575     Barisal Division
# 2018-08-15      BDT  Bangladesh       Dhaka     577       Dhaka Division
#
#             mktid  cmid  ptid  umid  catid           sn  default
# date
# 2005-10-15    118    58    15     5      1  118_58_15_5      NaN
# 2005-11-15    118    58    15     5      1  118_58_15_5      NaN
# 2005-11-15    116    58    15     5      1  116_58_15_5      NaN
# 2005-12-15    116    58    15     5      1  116_58_15_5      NaN
# 2006-01-15    114    58    15     5      1  114_58_15_5      NaN
# ...           ...   ...   ...   ...    ...          ...      ...
# 2018-08-15    120    58    15     5      1  120_58_15_5      NaN
# 2018-08-15    114    58    15     5      1  114_58_15_5      NaN
# 2018-08-15    118    58    15     5      1  118_58_15_5      NaN
# 2018-08-15    112    58    15     5      1  112_58_15_5      NaN
# 2018-08-15    116    58    15     5      1  116_58_15_5      NaN
#
# [870 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 870 entries, 2005-10-15 to 2018-08-15
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      870 non-null    datetime64[ns]
#  1   cmname    870 non-null    object
#  2   unit      870 non-null    object
#  3   category  870 non-null    object
#  4   price     870 non-null    float64
#  5   currency  870 non-null    object
#  6   country   870 non-null    object
#  7   admname   870 non-null    object
#  8   adm1id    870 non-null    int64
#  9   mktname   870 non-null    object
#  10  mktid     870 non-null    int64
#  11  cmid      870 non-null    int64
#  12  ptid      870 non-null    int64
#  13  umid      870 non-null    int64
#  14  catid     870 non-null    int64
#  15  sn        870 non-null    object
#  16  default   0 non-null      float64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(8)
# memory usage: 122.3+ KB

# %%
values = DataFrame(df['price'].values)
dataframe = concat([values.shift(1),values.shift(5),values.shift(10),values.shift(30), values], axis=1)
dataframe.columns = ['t', 't+1', 't+5', 't+10', 't+30']
result = dataframe.corr()
print(result)
# Out:
#              t       t+1       t+5      t+10      t+30
# t     1.000000  0.945292  0.912077  0.668814  0.959167
# t+1   0.945292  1.000000  0.941426  0.733364  0.941371
# t+5   0.912077  0.941426  1.000000  0.796014  0.902602
# t+10  0.668814  0.733364  0.796014  1.000000  0.656907
# t+30  0.959167  0.941371  0.902602  0.656907  1.000000

# %% [markdown]
# Split train and test data

# %%
train_data, test_data = df[0:-60], df[-60:]
plt.figure(figsize=(10,10))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(df['price'].tail(600), 'green', label='Train data')
plt.plot(test_data['price'], 'blue', label='Test data')
plt.legend()

# %% [markdown]
# Show the closing_price column data

# %%
df['price']
# Out:
# date
# 2005-10-15    20.000
# 2005-11-15    19.000
# 2005-11-15    20.000
# 2005-12-15    20.000
# 2006-01-15    21.000
#                ...
# 2018-08-15    30.743
# 2018-08-15    32.335
# 2018-08-15    32.017
# 2018-08-15    31.212
# 2018-08-15    31.979
# Name: price, Length: 870, dtype: float64

# %% [markdown]
# We take 60 days data to test our models

# %%
test_data.price.tail(30)
# Out:
# date
# 2018-04-15    32.038
# 2018-04-15    34.906
# 2018-04-15    33.125
# 2018-04-15    31.500
# 2018-04-15    31.143
# 2018-04-15    32.022
# 2018-05-15    31.844
# 2018-05-15    31.250
# 2018-05-15    32.014
# 2018-05-15    31.055
# 2018-05-15    32.788
# 2018-05-15    33.065
# 2018-06-15    33.125
# 2018-06-15    32.135
# 2018-06-15    32.510
# 2018-06-15    31.328
# 2018-06-15    31.928
# 2018-06-15    30.833
# 2018-07-15    31.448
# 2018-07-15    33.125
# 2018-07-15    30.833
# 2018-07-15    31.978
# 2018-07-15    32.056
# 2018-07-15    32.409
# 2018-08-15    33.125
# 2018-08-15    30.743
# 2018-08-15    32.335
# 2018-08-15    32.017
# 2018-08-15    31.212
# 2018-08-15    31.979
# Name: price, dtype: float64

# %%
train_data.price.tail(30)
# Out:
# date
# 2017-04-15    31.2222
# 2017-04-15    32.5000
# 2017-04-15    30.5000
# 2017-05-15    31.2222
# 2017-05-15    31.0000
# 2017-05-15    30.5000
# 2017-05-15    33.0000
# 2017-05-15    30.3846
# 2017-05-15    31.2857
# 2017-06-15    31.2857
# 2017-06-15    30.6882
# 2017-06-15    31.9175
# 2017-06-15    31.1000
# 2017-06-15    29.5288
# 2017-07-15    30.7500
# 2017-07-15    31.5050
# 2017-07-15    30.9000
# 2017-07-15    29.5113
# 2017-07-15    31.0800
# 2017-08-15    30.8200
# 2017-08-15    31.0000
# 2017-08-15    31.2000
# 2017-08-15    31.8600
# 2017-08-15    29.9413
# 2017-09-15    32.4450
# 2017-09-15    32.2980
# 2017-09-15    32.6844
# 2017-09-15    32.0308
# 2017-09-15    31.5587
# 2017-09-15    31.5709
# Name: price, dtype: float64

# %%
mean_value = df['price'].mean() # calculation of mean price

plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(df['price'], 'green', label='Train data')
plt.plot(test_data['price'], 'blue', label='Test data')
plt.axhline(y=mean_value, xmin=0.864, xmax=1, color='red')
plt.legend()

plt.figure(figsize=(16,8))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Open Prices')
plt.plot(df['price'].tail(600), 'green', label='Train data')
plt.plot(test_data['price'], 'blue', label='Test data')
plt.axhline(y=mean_value, xmin=0.864, xmax=1, color='red')
plt.legend()

print('MSE: '+str(mean_squared_error(test_data['price'], np.full(len(test_data), mean_value))))
print('MAE: '+str(mean_absolute_error(test_data['price'], np.full(len(test_data), mean_value))))
print('RMSE: '+str(sqrt(mean_squared_error(test_data['price'], np.full(len(test_data), mean_value)))))
# Out:
# MSE: 7.712001895524227
# MAE: 1.1106861762452103
# RMSE: 2.7770491345174695

# %% [markdown]
# Train data for ARIMA model

# %%
train_arima = train_data['price']
test_arima = test_data['price']

history = [x for x in train_arima]
y = test_arima
# make first prediction
predictions = list()
model = ARIMA(history, order=(1,1,0))
model_fit = model.fit(disp=0)
yhat = model_fit.forecast()[0]
predictions.append(yhat)
history.append(y[0])
# rolling forecasts
for i in range(1, len(y)):
    # predict
    model = ARIMA(history, order=(1,1,1))
    model_fit = model.fit(disp=0)
    yhat = model_fit.forecast()[0]
    # invert transformed prediction
    predictions.append(yhat)
    # observation
    obs = y[i]
    history.append(obs)
    
plt.figure(figsize=(14,8))
plt.plot(df.index, df['price'], color='green', label = 'Train  Price')
plt.plot(test_data.index, y, color = 'red', label = 'Real Price')
plt.plot(test_data.index, predictions, color = 'blue', label = 'Predicted  Price')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(14,8))
plt.plot(df.index[-600:], df['price'].tail(600), color='green', label = 'Train  Price')
plt.plot(test_data.index, y, color = 'red', label = 'Real  Price')
plt.plot(test_data.index, predictions, color = 'blue', label = 'Predicted  Price')
plt.legend()
plt.grid(True)
plt.show()

print('MSE: '+str(mean_squared_error(y, predictions)))
print('MAE: '+str(mean_absolute_error(y, predictions)))
print('RMSE: '+str(sqrt(mean_squared_error(y, predictions))))
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# MSE: 9.934997965489726
# MAE: 1.5841369338572584
# RMSE: 3.151983179759963

# %%
test_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Predicted result for ARIMA model

# %%
#y_test = df.iloc[int(7200): ,0:1].values
plt.figure(figsize=(6,3.5))
#plt.suptitle('Sine and cosine waves', fontsize=13)
plt.plot(predictions, color='blue', label='Predicted  price')
plt.plot(test_data['price'], color ='red', label='Actual  price')
plt.xlabel('Amount of days', fontsize=10)
plt.ylabel('Amount of price (Taka)', fontsize=10)
#plt.xticks(rotation=0,fontsize=12)
#plt.yticks(rotation=0,fontsize=12)
plt.grid(True)
#plt.savefig('ARIMA_Close_Price.jpeg')
plt.legend()
plt.show()

# %%
df.index  = df['date']
df
# Out:
#                  date                cmname unit            category   price  \
# date
# 2005-10-15 2005-10-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 2005-11-15 2005-11-15  Wheat flour - Retail   KG  cereals and tubers  19.000
# 2005-11-15 2005-11-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 2005-12-15 2005-12-15  Wheat flour - Retail   KG  cereals and tubers  20.000
# 2006-01-15 2006-01-15  Wheat flour - Retail   KG  cereals and tubers  21.000
# ...               ...                   ...  ...                 ...     ...
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  30.743
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  32.335
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  32.017
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  31.212
# 2018-08-15 2018-08-15  Wheat flour - Retail   KG  cereals and tubers  31.979
#
#            currency     country     admname  adm1id              mktname  \
# date
# 2005-10-15      BDT  Bangladesh      Khulna     578      Khulna Division
# 2005-11-15      BDT  Bangladesh      Khulna     578      Khulna Division
# 2005-11-15      BDT  Bangladesh       Dhaka     577       Dhaka Division
# 2005-12-15      BDT  Bangladesh       Dhaka     577       Dhaka Division
# 2006-01-15      BDT  Bangladesh  Chittagong     576  Chittagong Division
# ...             ...         ...         ...     ...                  ...
# 2018-08-15      BDT  Bangladesh    Rajshahi     579    Rajshahi Division
# 2018-08-15      BDT  Bangladesh  Chittagong     576  Chittagong Division
# 2018-08-15      BDT  Bangladesh      Khulna     578      Khulna Division
# 2018-08-15      BDT  Bangladesh     Barisal     575     Barisal Division
# 2018-08-15      BDT  Bangladesh       Dhaka     577       Dhaka Division
#
#             mktid  cmid  ptid  umid  catid           sn  default
# date
# 2005-10-15    118    58    15     5      1  118_58_15_5      NaN
# 2005-11-15    118    58    15     5      1  118_58_15_5      NaN
# 2005-11-15    116    58    15     5      1  116_58_15_5      NaN
# 2005-12-15    116    58    15     5      1  116_58_15_5      NaN
# 2006-01-15    114    58    15     5      1  114_58_15_5      NaN
# ...           ...   ...   ...   ...    ...          ...      ...
# 2018-08-15    120    58    15     5      1  120_58_15_5      NaN
# 2018-08-15    114    58    15     5      1  114_58_15_5      NaN
# 2018-08-15    118    58    15     5      1  118_58_15_5      NaN
# 2018-08-15    112    58    15     5      1  112_58_15_5      NaN
# 2018-08-15    116    58    15     5      1  116_58_15_5      NaN
#
# [870 rows x 17 columns]

# %% [markdown]
# Pre-process data for Prophet model

# %%
ph_df_train = train_data.drop(['cmname', 'unit', 'category','currency',
                               'country','admname','adm1id','mktname','mktid',
                               'cmid','ptid','umid','catid','sn','default'], axis=1)
ph_df_train['date'] = ph_df_train.index
ph_df_train.rename(columns={'price': 'y', 'date': 'ds'}, inplace=True)

prop = Prophet(changepoint_prior_scale=0.1)
prop.fit(ph_df_train)
# Create Future dates
future_prices = prop.make_future_dataframe(periods=73)

# Predict Prices
forecast = prop.predict(future_prices)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpt1qiv5qs/jfw9qe2p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpt1qiv5qs/qdj6w1bj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2440', 'data', 'file=/tmp/tmpt1qiv5qs/jfw9qe2p.json', 'init=/tmp/tmpt1qiv5qs/qdj6w1bj.json', 'output', 'file=/tmp/tmpqxp95_yn/prophet_model-20220905093401.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 09:34:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 09:34:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast['yhat']
# Out:
# 0      18.500582
# 1      19.149525
# 2      19.110825
# 3      19.124988
# 4      20.518015
#          ...
# 211    36.204721
# 212    36.770016
# 213    37.232787
# 214    37.577109
# 215    37.790929
# Name: yhat, Length: 216, dtype: float64

# %%
test_data.index  = test_data['date']

# %%
plt.figure(figsize=(14,8))
plt.plot(df.index, df['price'], color='green', label = 'Train  Price')
plt.plot(test_data.index, test_data['price'], color = 'red', label = 'Real  Price')
plt.plot(test_data.index, forecast['yhat'][-60:], color = 'blue', label = 'Predicted  Price')
plt.fill_between(test_data.index, forecast['yhat_lower'][-60:], forecast['yhat_upper'][-60:], color='grey', label="Band Range")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.plot(df.index, df['price'], color='green', label = 'Train  Price')
plt.plot(test_data.index, test_data['price'], color = 'red', label = 'Real Price')
plt.plot(test_data.index, forecast['yhat'][-60:], color = 'blue', label = 'Predicted  Price')
plt.fill_between(test_data.index, forecast['yhat_lower'][-60:], forecast['yhat_upper'][-60:], color='grey', label="Band Range")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(14,8))
plt.plot(df.index[-600:], df['price'].tail(600), color='green', label = 'Train  Price')
plt.plot(test_data.index, test_data['price'], color = 'red', label = 'Real  Price')
plt.plot(test_data.index, forecast['yhat'][-60:], color = 'blue', label = 'Predicted  Price')
plt.fill_between(test_data.index, forecast['yhat_lower'][-60:], forecast['yhat_upper'][-60:], color='grey', label="Band Range")
plt.legend()
plt.grid(True)
plt.show()
print('MSE: '+str(mean_squared_error(test_data['price'], forecast['yhat'][-60:])))
print('MAE: '+str(mean_absolute_error(test_data['price'], forecast['yhat'][-60:])))
print('RMSE: '+str(sqrt(mean_squared_error(test_data['price'], forecast['yhat'][-60:]))))
# Out:
# MSE: 32.96745655856025
# MAE: 4.623392957684435
# RMSE: 5.74172940485358

# %%
train = train_data.iloc[:, 4:5].values # selecting open prices
# Feature Scaling
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train) 
# Train dataset
timesteps = 7
X_train = []
y_train = []
for i in range(timesteps, train.shape[0]):
    X_train.append(train_scaled[i-timesteps:i, 0]) # we take 30 previous prices
    y_train.append(train_scaled[i, 0]) # and 60-th price as y value
X_train, y_train = np.array(X_train), np.array(y_train)
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
from numpy.random import seed
seed(2019)

# %% [markdown]
# LSTM model training

# %%
model = Sequential()

# Adding the first LSTM layer 
# Here return_sequences=True means whether to return the last output in the output sequence, or the full sequence.
# it basically tells us that there is another(or more) LSTM layer ahead in the network.
model.add(LSTM(units = 60, return_sequences = True, input_shape = (X_train.shape[1], 1)))
# Dropout regularisation for tackling overfitting
#model.add(Dropout(0.2))

model.add(LSTM(units = 50))
#model.add(Dropout(0.25))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
# RMSprop is a recommended optimizer as per keras documentation
# check out https://keras.io/optimizers/ for more details
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 100, batch_size = 16)
# Out:
# Epoch 1/100
# 51/51 [==============================] - 4s 5ms/step - loss: 0.0320
# Epoch 2/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 3/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 4/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 5/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 6/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 7/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 8/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 9/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 10/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 11/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 12/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 13/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 14/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 15/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 16/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 17/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 18/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 19/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 20/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 21/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 22/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 23/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 24/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 25/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 26/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 27/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 28/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 29/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 30/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 31/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 32/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 33/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 34/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 35/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 36/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 37/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 38/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 39/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 40/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 41/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 42/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 43/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 44/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 45/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 46/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 47/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 48/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 49/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 50/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 51/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 52/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 53/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 54/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 55/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 56/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 57/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 58/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 59/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 60/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 61/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 62/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 63/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 64/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 65/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 66/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 67/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 68/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 69/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 70/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 71/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 72/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 73/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 74/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 75/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 76/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 77/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 78/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 79/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 80/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 81/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 82/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 83/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 84/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 85/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 86/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 87/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 88/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 89/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 90/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 91/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 92/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 93/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 94/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 95/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 96/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 97/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0018
# Epoch 98/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 99/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 100/100
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021

# %%
# this will be used later while comparing and visualization
real_stock_price = test_data.iloc[:,4:5].values # taking open price
# combine original train and test data vertically
# as previous Open Prices are not present in test dataset
# e.g. for predicting Open price for first date in test data, we will need stock open prices on timesteps previous dates  
combine = pd.concat((train_data['price'], test_data['price']), axis = 0)
# our test inputs also contains stock open Prices of last timesteps dates (as described above)
test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
# same steps as we followed while processing training data
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
# inverse_transform because prediction is done on scaled inputs
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

# %% [markdown]
# Predicted result for LSTM model

# %%
plt.figure(figsize=(16,8))
plt.plot(df.index[-600:], df['price'].tail(600), color='green', label = 'Train  Price')
plt.plot(test_data.index, real_stock_price, color = 'red', label = 'Real  Price')
plt.plot(test_data.index, predicted_stock_price, color = 'blue', label = 'Predicted  Price')
plt.title(' price Prediction')
plt.xlabel('Time')
plt.ylabel(' price')
plt.legend()
plt.grid(True)
#plt.savefig('lstm_30.pdf')
plt.show()

mse = mean_squared_error(real_stock_price, predicted_stock_price)
print('MSE: '+str(mse))
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
print('MAE: '+str(mae))
rmse = sqrt(mean_squared_error(real_stock_price, predicted_stock_price))
print('RMSE: '+str(rmse))
# Out:
# MSE: 9.982658664136084
# MAE: 1.590774608968099
# RMSE: 3.159534564478775

# %%
test_data.reset_index(drop=True, inplace=True)
#y_test = df.iloc[int(7200): ,0:1].values
plt.figure(figsize=(6,3.5))
#plt.suptitle('Sine and cosine waves', fontsize=13)
plt.plot(predicted_stock_price, color='blue', label='Predicted  Price')
plt.plot(test_data['price'], color ='red', label='Actual  Price')
plt.xlabel('Amount of days', fontsize=10)
plt.ylabel('Amount of price (Taka)', fontsize=10)
#plt.xticks(rotation=0,fontsize=12)
#plt.yticks(rotation=0,fontsize=12)
plt.grid(True)
#plt.savefig('LSTM_opening_price.jpeg')
plt.legend()
plt.show()

# %% [markdown]
# Training data by GRU model

# %%
model = Sequential()

# Adding the first GRU layer 
# Here return_sequences=True means whether to return the last output in the output sequence, or the full sequence.
# it basically tells us that there is another(or more) GRU layer ahead in the network.
model.add(GRU(units = 60, return_sequences = True, input_shape = (X_train.shape[1], 1)))
# Dropout regularisation for tackling overfitting
model.add(Dropout(0.2))

model.add(GRU(units = 50))
model.add(Dropout(0.25))

# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
# RMSprop is a recommended optimizer as per keras documentation
# check out https://keras.io/optimizers/ for more details
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, epochs = 200, batch_size = 16)
# Out:
# Epoch 1/200
# 51/51 [==============================] - 3s 5ms/step - loss: 0.0345
# Epoch 2/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 3/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0058
# Epoch 4/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0057
# Epoch 5/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0053
# Epoch 6/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 7/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 8/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 9/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 10/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 11/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0045
# Epoch 12/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0048
# Epoch 13/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 14/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 15/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0043
# Epoch 16/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0042
# Epoch 17/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 18/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0040
# Epoch 19/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 20/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 21/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 22/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0041
# Epoch 23/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 24/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 25/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 26/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0037
# Epoch 27/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0036
# Epoch 28/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 29/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0038
# Epoch 30/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 31/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0035
# Epoch 32/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 33/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 34/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 35/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 36/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 37/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 38/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 39/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0033
# Epoch 40/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 41/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 42/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 43/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 44/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 45/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 46/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 47/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 48/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 49/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 50/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 51/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 52/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0032
# Epoch 53/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0031
# Epoch 54/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 55/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 56/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 57/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 58/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 59/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 60/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 61/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0028
# Epoch 62/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 63/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 64/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 65/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 66/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 67/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 68/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 69/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 70/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 71/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 72/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 73/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 74/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 75/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 76/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 77/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 78/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 79/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 80/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 81/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 82/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 83/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 84/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 85/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 86/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 87/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 88/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 89/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 90/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 91/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 92/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 93/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 94/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 95/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 96/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 97/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0029
# Epoch 98/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 99/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 100/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 101/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 102/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 103/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 104/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 105/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 106/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 107/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 108/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 109/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 110/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 111/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 112/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 113/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 114/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 115/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 116/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 117/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 118/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 119/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 120/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 121/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 122/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 123/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 124/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 125/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 126/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 127/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 128/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 129/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0024
# Epoch 130/200
# 51/51 [==============================] - 0s 8ms/step - loss: 0.0026
# Epoch 131/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 132/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0024
# Epoch 133/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0023
# Epoch 134/200
# 51/51 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 135/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 136/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0023
# Epoch 137/200
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0022
# Epoch 138/200
# 51/51 [==============================] - 0s 7ms/step - loss: 0.0022
# Epoch 139/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 140/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 141/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 142/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 143/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 144/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 145/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 146/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 147/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 148/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 149/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 150/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 151/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 152/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 153/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 154/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 155/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 156/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 157/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 158/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 159/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 160/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0020
# Epoch 161/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 162/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 163/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 164/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 165/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 166/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 167/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 168/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 169/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 170/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 171/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 172/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 173/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 174/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0021
# Epoch 175/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 176/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 177/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 178/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 179/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 180/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0024
# Epoch 181/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 182/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 183/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 184/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 185/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 186/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 187/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 188/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 189/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 190/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0025
# Epoch 191/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 192/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 193/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 194/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 195/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 196/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 197/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 198/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 199/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023
# Epoch 200/200
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0023

# %%
# this will be used later while comparing and visualization
real_stock_price_GRU = test_data.iloc[:,4:5].values # taking open price
# combine original train and test data vertically
# as previous Open Prices are not present in test dataset
# e.g. for predicting Open price for first date in test data, we will need stock open prices on timesteps previous dates  
combine = pd.concat((train_data['price'], test_data['price']), axis = 0)
# our test inputs also contains stock open Prices of last timesteps dates (as described above)
test_inputs = combine[len(combine) - len(test_data) - timesteps:].values
test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)
# same steps as we followed while processing training data
X_test = []
for i in range(timesteps, test_data.shape[0]+timesteps):
    X_test.append(test_inputs[i-timesteps:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price_GRU = model.predict(X_test)
# inverse_transform because prediction is done on scaled inputs
predicted_stock_price_GRU = scaler.inverse_transform(predicted_stock_price_GRU)

# %%
test_data.index  = test_data['date']

# %%
plt.figure(figsize=(16,8))
plt.plot(df.index[-600:], df['price'].tail(600), color='green', label = 'Train Price')
plt.plot(test_data.index, real_stock_price_GRU, color = 'red', label = 'Real  Price')
plt.plot(test_data.index, predicted_stock_price_GRU, color = 'blue', label = 'Predicted  Price')
plt.title(' price Prediction')
plt.xlabel('Time')
plt.ylabel(' Closing price')
plt.legend()
plt.grid(True)
plt.savefig('lstm_30.pdf')
plt.show()


mse = mean_squared_error(real_stock_price_GRU, predicted_stock_price_GRU)
print('MSE: '+str(mse))
mae = mean_absolute_error(real_stock_price_GRU, predicted_stock_price_GRU)
print('MAE: '+str(mae))
rmse = sqrt(mean_squared_error(real_stock_price_GRU, predicted_stock_price_GRU))
print('RMSE: '+str(rmse))
# Out:
# MSE: 9.336486957465091
# MAE: 1.4345076098632812
# RMSE: 3.0555665526159124

# %%
plt.figure(figsize=(16,8))
#print('Lag: %s' % model_fit.k_ar)
plt.plot(df.index[-100:], df['price'].tail(100), color='green', label=' price')
plt.plot(test_data.index, test_data['price'], color='red', label='Test  price')
plt.plot(test_data.index, predicted_stock_price_GRU, color='blue', label='Predicted  price')
plt.xlabel('Date', fontsize=10)
plt.xticks(rotation=90,fontsize=7)
#plt.grid(True)
plt.legend()
